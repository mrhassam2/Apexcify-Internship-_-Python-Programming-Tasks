# %%
# TASK 1: Email Automation System
# Simulated version for internship demo (no real email sending)

# Predefined list of 20 emails
emails = [
    "user1@example.com", "user2@example.com", "user3@example.com", "user4@example.com", "user5@example.com",
    "user6@example.com", "user7@example.com", "user8@example.com", "user9@example.com", "user10@example.com",
    "user11@example.com", "user12@example.com", "user13@example.com", "user14@example.com", "user15@example.com",
    "user16@example.com", "user17@example.com", "user18@example.com", "user19@example.com", "user20@example.com"
]

# Take subject and body from user
subject = input("Enter subject: ")
body = input("Enter message body: ")

print("\n📧 Sending emails...\n")

# Simulate sending
for receiver in emails:
    print(f"✅ Email sent to {receiver}")
    print(f"   Subject: {subject}")
    print(f"   Message: {body}\n")

print("🎉 All emails sent successfully (simulation)!")
# Out:
# Enter subject: Internship
# Enter message body: I am doing an internship in Apexcify. Its really cool.
#
# 📧 Sending emails...
#
# ✅ Email sent to user1@example.com
#    Subject: Internship
#    Message: I am doing an internship in Apexcify. Its really cool.
#
# ✅ Email sent to user2@example.com
#    Subject: Internship
#    Message: I am doing an internship in Apexcify. Its really cool.
#
# ✅ Email sent to user3@example.com
#    Subject: Internship
#    Message: I am doing an internship in Apexcify. Its really cool.
#
# ✅ Email sent to user4@example.com
#    Subject: Internship
#    Message: I am doing an internship in Apexcify. Its really cool.
#
# ✅ Email sent to user5@example.com
#    Subject: Internship
#    Message: I am doing an internship in Apexcify. Its really cool.
#
# ✅ Email sent to user6@example.com
#    Subject: Internship
#    Message: I am doing an internship in Apexcify. Its really cool.
#
# ✅ Email sent to user7@example.com
#    Subject: Internship
#    Message: I am doing an internship in Apexcify. Its really cool.
#
# ✅ Email sent to user8@example.com
#    Subject: Internship
#    Message: I am doing an internship in Apexcify. Its really cool.
#
# ✅ Email sent to user9@example.com
#    Subject: Internship
#    Message: I am doing an internship in Apexcify. Its really cool.
#
# ✅ Email sent to user10@example.com
#    Subject: Internship
#    Message: I am doing an internship in Apexcify. Its really cool.
#
# ✅ Email sent to user11@example.com
#    Subject: Internship
#    Message: I am doing an internship in Apexcify. Its really cool.
#
# ✅ Email sent to user12@example.com
#    Subject: Internship
#    Message: I am doing an internship in Apexcify. Its really cool.
#
# ✅ Email sent to user13@example.com
#    Subject: Internship
#    Message: I am doing an internship in Apexcify. Its really cool.
#
# ✅ Email sent to user14@example.com
#    Subject: Internship
#    Message: I am doing an internship in Apexcify. Its really cool.
#
# ✅ Email sent to user15@example.com
#    Subject: Internship
#    Message: I am doing an internship in Apexcify. Its really cool.
#
# ✅ Email sent to user16@example.com
#    Subject: Internship
#    Message: I am doing an internship in Apexcify. Its really cool.
#
# ✅ Email sent to user17@example.com
#    Subject: Internship
#    Message: I am doing an internship in Apexcify. Its really cool.
#
# ✅ Email sent to user18@example.com
#    Subject: Internship
#    Message: I am doing an internship in Apexcify. Its really cool.
#
# ✅ Email sent to user19@example.com
#    Subject: Internship
#    Message: I am doing an internship in Apexcify. Its really cool.
#
# ✅ Email sent to user20@example.com
#    Subject: Internship
#    Message: I am doing an internship in Apexcify. Its really cool.
#
# 🎉 All emails sent successfully (simulation)!
